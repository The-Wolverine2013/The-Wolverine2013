# %%
#task 2

class Spaceship:
    def __init__(self, name, capacity):
        self.name = name
        self.capacity = capacity
        self.current_cargo_weight = 0
        self.cargo_items = []
    def load_cargo(self, cargo):
        if self.current_cargo_weight + cargo.get_weight() > self.capacity:
           print(f"Warning: Unable to load {cargo.get_name()} inside {self.name}. Exceeds capacity by {self.current_cargo_weight + cargo.get_weight() - self.capacity}.")
        else:
            self.cargo_items.append(cargo)
            self.current_cargo_weight += cargo.get_weight()
    def display_details(self):
        print(f"Spaceship Name: {self.name}")
        print(f"Capacity: {self.capacity}")
        print(f"Current Cargo Weight: {self.current_cargo_weight}")
        print(f"Cargo: {[cargo.get_name() for cargo in self.cargo_items]}")
class Cargo:
    def __init__(self, name, weight):
        self.__name = name
        self.__weight = weight

    def get_name(self):
        return self.__name

    def get_weight(self):
        return self.__weight
falcon = Spaceship("Falcon", 50000)
apollo = Spaceship("Apollo", 100000)
enterprise = Spaceship("Enterprise", 220000)
print("1.===================================")
gold = Cargo("Gold", 20000)
platinum = Cargo("Platinum", 25000)
dilithium = Cargo("Dilithium", 50000)
trilithium = Cargo("Trilithium", 70000)
neutronium = Cargo("Neutronium", 80000)
print("2.===================================")
falcon.load_cargo(gold)
falcon.load_cargo(platinum)
falcon.display_details()
print("3.===================================")
apollo.load_cargo(gold)
apollo.display_details()
print("4.===================================")
falcon.load_cargo(neutronium)
print("5.===================================")
enterprise.load_cargo(dilithium)
enterprise.load_cargo(trilithium)
enterprise.load_cargo(neutronium)
enterprise.display_details()
# Out:
# 1.===================================
# 2.===================================
# Spaceship Name: Falcon
# Capacity: 50000
# Current Cargo Weight: 45000
# Cargo: ['Gold', 'Platinum']
# 3.===================================
# Spaceship Name: Apollo
# Capacity: 100000
# Current Cargo Weight: 20000
# Cargo: ['Gold']
# 4.===================================
# ...
# 5.===================================
# Spaceship Name: Enterprise
# Capacity: 220000
# Current Cargo Weight: 200000
# Cargo: ['Dilithium', 'Trilithium', 'Neutronium']

# %%
#1
class Student:
    names = []
    ids = []
    cgs = []
    def __init__(self, name, id, cg):
        self.name = name
        self.__id = id
        self.__cg = cg
        if self.__id not in Student.ids:
            Student.ids.append(self.__id)
            Student.names.append(self.name)
            Student.cgs.append(self.__cg)

        elif self.__id in Student.ids:
            self.__id = None
            print("Student with the same ID already exists, Please try with another ID")

    def setId(self, id):
        self.__id = id
        if self.__id not in Student.ids:
            Student.ids.append(self.__id)

    def getId(self):
        return self.__id

    def getCg(self):
        return self.__cg

    def getName(self):
        return self.name

class Department:
    def __init__(self, dept):
        self.d = dept
        self.ref = []

    def findStudent(self, id):
        self.id = id
        if self.id in Student.ids:
            for x in self.ref:
                if self.id == x.getId():
                    print("Student info:")
                    print(f"Student Name: {x.getName()}")
                    print(f"ID: {x.getId()}")
                    print(f"CGPA: {x.getCg()}")

        elif self.id not in Student.ids:
            print("Student with this ID doesn't exist, Please give a valid ID")

    def addStudent(self, *references):
        for x in references:
            if x.getId() != None:
                self.ref.append(x)
                print(f"Welcome to {self.d} department, {x.getName()}")

    def details(self):
        print(f"Department Name: {self.d}")
        print(f"Number of student:{len(self.ref)}")
        print("Details of the students:")
        for x in self.ref:
            print(f"Student name: {x.getName()}, ID: {x.getId()}, cgpa: {x.getCg()}")

s1 = Student("Akib", 22301010, 3.29)
s2 = Student("Reza", 22101010, 3.45)
s3 = Student("Ruhan", 23101934, 4.00)
print("1==================================")
cse = Department("CSE")
cse.findStudent(22112233)
print("2==================================")
cse.addStudent(s1,s2,s3)
print("3==================================")
cse.details()
print("4==================================")
cse.findStudent(22301010)
print("5==================================")
s4 = Student("Nakib",22301010,3.22)
cse.addStudent(s4)
print("6==================================")
s4.setId(21201220)
cse.addStudent(s4)
print("7==================================")
cse.details()
print("8==================================")
s5 = Student("Sakib",22201010,2.29)
cse.addStudent(s5)
print("9==================================")
cse.details()
# Out:
# 1==================================
# Student with this ID doesn't exist, Please give a valid ID
# 2==================================
# Welcome to CSE department, Akib
# Welcome to CSE department, Reza
# Welcome to CSE department, Ruhan
# 3==================================
# Department Name: CSE
# Number of student:3
# Details of the students:
# Student name: Akib, ID: 22301010, cgpa: 3.29
# Student name: Reza, ID: 22101010, cgpa: 3.45
# Student name: Ruhan, ID: 23101934, cgpa: 4.0
# 4==================================
# Student info:
# Student Name: Akib
# ID: 22301010
# CGPA: 3.29
# 5==================================
# Student with the same ID already exists, Please try with another ID
# 6==================================
# Welcome to CSE department, Nakib
# 7==================================
# Department Name: CSE
# Number of student:4
# Details of the students:
# Student name: Akib, ID: 22301010, cgpa: 3.29
# Student name: Reza, ID: 22101010, cgpa: 3.45
# ...

# %%
class Author:
    def __init__(self, name, birth_year):
        self.name = name
        self.birth_year = birth_year

class Book:
    def __init__(self, title, author, publication_year):
        self.title = title
        self.author = author
        self.publication_year = publication_year

    def display_info(self):
        print(f"Title: {self.title}")
        print(f"Author: {self.author.name}")
        print(f"Author's Birth Year: {self.author.birth_year}")
        print(f"Publication Year: {self.publication_year}")

# Creating an Author instance
author1 = Author("J.K. Rowling", 1965)

# Creating a Book instance with the Author
book1 = Book("Harry Potter and the Sorcerer's Stone", author1, 1997)

# Displaying book information
book1.display_info()
# Out:
# Title: Harry Potter and the Sorcerer's Stone
# Author: J.K. Rowling
# Author's Birth Year: 1965
# Publication Year: 1997

# %%
class Student:
  def __init__(self,name,id,cgpa):
    self.name=name
    self.__id=id
    self.__cgpa=cgpa
  def setId(self,id):
    self.__id=id
  def getId(self):
    return self.__id
  def getCgpa(self):
    return self.__cgpa
class Department:
  def __init__(self,dep):
     self.department = dep
     self.student_details = {}
  def addStudent(self, *args):
     for i in args:
        if i.getId() in self.student_details:
           self.student_details[i.getId()] = (i.name,i.getCgpa())
           print("Student with the same ID already exists, Please try with another ID")
        else:
           print(f"Welcome to {self.department}, {i.name}")
           self.student_details[i.getId()] = [i.name,i.getCgpa()]
  def findStudent(self,id):
     if id in self.student_details:
           name, cg = self.student_details[id]
           print("Student info:")
           print(f"Student Name: {name}")
           print(f"ID: {id}\nCGPA: {cg}")
     else:
            print("Student with this ID doesn't exist, Please give a valid ID")
  def details(self):
     print(f"Department Name: {self.department}")
     print(f"Number of student: {len(self.student_details)}")
     print(f"Details of the students:")
     for id, value in self.student_details.items():
        name, cg = value
        print(f"Student Name: {name}, ID: {id}, cgpa: {cg}")
s1 = Student("Akib", 22301010, 3.29)
s2 = Student("Reza", 22101010, 3.45)
s3 = Student("Ruhan", 23101934, 4.00)
print("1==================================")
cse = Department("CSE")
cse.findStudent(22112233)
print("2==================================")
cse.addStudent(s1,s2,s3)
print("3==================================")
cse.details()
print("4==================================")
cse.findStudent(22301010)
print("5==================================")
s4 = Student("Nakib",22301010,3.22)
cse.addStudent(s4)
print("6==================================")
s4.setId(21201220)
cse.addStudent(s4)
print("7==================================")
cse.details()
print("8==================================")
s5 = Student("Sakib",22201010,2.29)
cse.addStudent(s5)
print("9==================================")
cse.details()
# Out:
# 1==================================
# Student with this ID doesn't exist, Please give a valid ID
# 2==================================
# Welcome to CSE, Akib
# Welcome to CSE, Reza
# Welcome to CSE, Ruhan
# 3==================================
# Department Name: CSE
# Number of student: 3
# Details of the students:
# Student Name: Akib, ID: 22301010, cgpa: 3.29
# Student Name: Reza, ID: 22101010, cgpa: 3.45
# Student Name: Ruhan, ID: 23101934, cgpa: 4.0
# 4==================================
# Student info:
# Student Name: Akib
# ID: 22301010
# CGPA: 3.29
# 5==================================
# Student with the same ID already exists, Please try with another ID
# 6==================================
# Welcome to CSE, Nakib
# 7==================================
# Department Name: CSE
# Number of student: 4
# Details of the students:
# Student Name: Nakib, ID: 22301010, cgpa: 3.22
# Student Name: Reza, ID: 22101010, cgpa: 3.45
# Student Name: Ruhan, ID: 23101934, cgpa: 4.0
# ...

# %%
#task 3

class song:
  def __init__(self,title,duration=0,artist="Unknown Artist"):
    self.__title=title
    self.__duration=duration
    self.__artist=0

  def set_title(self,title):
    self.__title=title

  def get_title(self):
    return self.__title

  def set_duration(self,duration):
    self.__duration=duration

  def get_duration(self):
    return self.__duration

  def set_artist(self,artist):
    self.__artist=artist

  def get_artist(self):
    return self.__artis
    t
  def info(self):
    if self.__duration==0:
      return ("Cannot create song without title and duration!\n--- Error --- by --- Error --- (0:0)")

    else:
      sec=self.__duration//60
      min=self.__duration%60
      return (f"{self.__title} by {self.__artist} ({min}:{sec}")

class Playlist:
  def __init__(self,name,*args):
    self.__name=name
    self.__song_list=[]
    self.__id=-1
    for i in args:
       self.__song_list.append(i)

  def add_songs(self,*add):
    self.add=add
    for i in add:
      self.__song_list.append(i)

  def play_next(self):
    self.__id+=1
    if self.__id>(len(self.__song_list)-1):
      print(f"Reached the end of the playlist, starting from the first song.")
      self.__id=0
      print(f"Now playing: {self.__song_list[self.__id].get_title()} by {self.__song_list[self.__id].get_artist()} ({((self.__song_list[self.__id].get_duration())//60)}:{((self.__song_list[self.__id].get_duration())%60)})")
    else:
      print(f"Now playing: {self.__song_list[self.__id].get_title()} by {self.__song_list[self.__id].get_artist()} ({((self.__song_list[self.__id].get_duration())//60)}:{((self.__song_list[self.__id].get_duration())%60)})")

  def play_prev(self):
    self.__id-=1
    if self.__id==-1:
      print(f"Cannot go to previous from the first song.")
      self.__id+=1
      print(f"Now playing: {self.__song_list[self.__id].get_title()} by {self.__song_list[self.__id].get_artist()} ({((self.__song_list[self.__id].get_duration())//60)}:{((self.__song_list[self.__id].get_duration())%60)})")
    else:
      print(f"Now playing: {self.__song_list[self.__id].get_title()} by {self.__song_list[self.__id].get_artist()} ({((self.__song_list[self.__id].get_duration())//60)}:{((self.__song_list[self.__id].get_duration())%60)})")

  def show_playlist(self):
    print(f"Playlist: {self.__name}\nTotal Songs: {len(self.__song_list)}")
    for i in range (0,len(self.__song_list)):
      print(f"{i+1}. {self.__song_list[i].get_title()} by {self.__song_list[i].get_artist()} ({((self.__song_list[i].get_duration())//60)}:{((self.__song_list[i].get_duration())%60)})")

s1 = Song("The Flower Duet",86,"Leo Delibes")
print(s1.info())
print('===============')
s2 = Song("Winter")
print(s2.info())
print('===============')
s2.set_title("Winter")
s2.set_duration(223)
s2.set_artist("Vivaldi")
print(s2.info())
print('===============')
s3 = Song("Ride of the Valkyries", 137, "Wagner" )
s4 = Song("Russian Dance-Nutcracker", 71)
p1 = Playlist("Classical Orchestra", s1, s2, s3)
p1.show_playlist()
print('===============')
p1.play_next()
print('===============')
p1.play_prev()
print('===============')
p1.play_next()
print('===============')
p1.play_next()
print('===============')
p1.play_next()
print('===============')
p1.play_next()
print('===============')
p1.add_songs(s4)
print('===============')
p1.play_next()
print('===============')
p1.play_next()
print('===============')
p1.play_prev()
print('===============')
p1.show_playlist()
# Out:
# The Flower Duet by Leo Delibes (1:26)
# ...
# Cannot create song without title and duration!
# --- Error --- by --- Error --- (0:0)
# ...
# Winter by Vivaldi (3:43)
# ...
# Playlist: Classical Orchestra
# Total Songs: 3
# 1. The Flower Duet by Leo Delibes (1:26)
# 2. Winter by Vivaldi (3:43)
# 3. Ride of the Valkyries by Wagner (2:17)
# ...
# Now playing: The Flower Duet by Leo Delibes (1:26)
# ...
# Cannot go to previous from the first song.
# Now playing: The Flower Duet by Leo Delibes (1:26)
# ...
# Now playing: Winter by Vivaldi (3:43)
# ...
# Now playing: Ride of the Valkyries by Wagner (2:17)
# ...
# Reached the end of the playlist, starting from the first song.
# Now playing: The Flower Duet by Leo Delibes (1:26)
# ...
# Now playing: Winter by Vivaldi (3:43)
# ...
# Now playing: Ride of the Valkyries by Wagner (2:17)
# ...
# Now playing: Russian Dance-Nutcracker by Unknown Artist (1:11)
# ...
# Now playing: Ride of the Valkyries by Wagner (2:17)
# ...
# Playlist: Classical Orchestra
# Total Songs: 4
# 1. The Flower Duet by Leo Delibes (1:26)
# ...
