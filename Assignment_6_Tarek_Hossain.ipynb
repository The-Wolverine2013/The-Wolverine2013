# %% [markdown]
# HOMEWORK

# %%
class Movie:

  def __init__(self,name,genre,duration):
    self.name=name
    self.genre=genre
    self.duration=duration

  def movieInfo(self):
    return f"Movie Name: {self.name}\nMovie Genre:{self.genre}\nMovie Duration:{self.duration} Minutes."

  @classmethod
  def createMovie_fromString(cls,string):
    name,genre,duration=string.split("-")
    return cls(name,genre,duration)

class StarCinema:

  all_branch_info={}

  def __init__(self,loc):
    self.branch_name=loc
    self.movie_list=[]
    StarCinema.all_branch_info[self.branch_name]=[]
    print(f"Welcome to {self.branch_name} branch of star cinema!")

  def addMovies(self,*movie_objects):
    for i in movie_objects:
      if i in self.movie_list:
        print("Movie is already added in this branch.")
      else:
        #print("Movie is already added in this branch.")
        self.movie_list.append(i)
        StarCinema.all_branch_info[self.branch_name].append(i)
        print(f"{i.name} added to {self.branch_name} branch.")

  def removeMovie(self,Movie_object):
    if Movie_object in self.movie_list:
      self.movie_list.remove(Movie_object)
    #else:
      #print("This movie is not in the list to remove.")

  @classmethod
  def check(cls,film):
    boole=False
    for k,v in cls.all_branch_info.items():
      for j in v:
        if j.name==film:
          print(f"{film} is being streamed in {k} branch.")
          boole=True
      if boole!=True:
          print(film,"is not being streamed in any branch.")
      else:
          print(f"It is of {j.genre} genre and {j.duration} minutes duration.")

  @classmethod
  def showAllBranchInfo(cls):
    for x,y in cls.all_branch_info.items():
      print("Branch Name:",x)
      for t in range((len(y))):
        print("Movie No:",(t+1))
        print(y[t].movieInfo())
        print("*********************")
      print("################################")


movie1 = Movie('Oppenheimer', 'Biographical Drama', 180)
movie2 = Movie('Barbie', 'Fantasy Comedy', 114)
movie3 = Movie('Mission: Impossible – Dead Reckoning Part One', 'Action', 163)
print('1==========================================')
print(movie3.movieInfo())
print('2==========================================')
movie4 = Movie.createMovie_fromString('Prohelika-Drama-153')
print('3==========================================')
print(movie4.movieInfo())
print('4==========================================')
branch1 = StarCinema('Mohakhali')
print('5==========================================')
branch1.addMovies(movie1, movie2, movie4)
print('6==========================================')
branch1.addMovies(movie1, movie3)
print('7==========================================')
StarCinema.showAllBranchInfo()
print('8==========================================')
branch2 = StarCinema('Mirpur')
print('9==========================================')
branch2.addMovies(movie1, movie2, movie3)
print('10==========================================')
StarCinema.showAllBranchInfo()
print('11==========================================')
StarCinema.check('Oppenheimer')
print('12=========================================')
StarCinema.check('Sound of Freedom')
print('13=========================================')
branch1.removeMovie(movie2)
StarCinema.showAllBranchInfo()
print('14=========================================')
branch2.removeMovie(movie1)
StarCinema.showAllBranchInfo()
# Out:
# 1==========================================
# Movie Name: Mission: Impossible – Dead Reckoning Part One
# Movie Genre:Action
# Movie Duration:163 Minutes.
# 2==========================================
# 3==========================================
# Movie Name: Prohelika
# Movie Genre:Drama
# Movie Duration:153 Minutes.
# 4==========================================
# Welcome to Mohakhali branch of star cinema!
# 5==========================================
# Oppenheimer added to Mohakhali branch.
# Barbie added to Mohakhali branch.
# Prohelika added to Mohakhali branch.
# 6==========================================
# Movie is already added in this branch.
# Mission: Impossible – Dead Reckoning Part One added to Mohakhali branch.
# 7==========================================
# Branch Name: Mohakhali
# Movie No: 1
# Movie Name: Oppenheimer
# Movie Genre:Biographical Drama
# Movie Duration:180 Minutes.
# *********************
# Movie No: 2
# Movie Name: Barbie
# ...

# %%
class Movie:
  def __init__(self,name,genre,dur):
    self.name = name
    self.genre = genre
    self.duration = dur

  def movieInfo(self):
    return f"Movie Name: {self.name}\nMovie Genre: {self.genre}\nMovie Duration: {self.duration} minutes"

  @classmethod
  def createMovie_fromString(cls,string):
    name,genre,duration=string.split("-")
    return cls(name,genre,duration)

class StarCinema:
  all_branch_info={}
  def __init__(self,bname):
    self.branch_name=bname
    self.movie_list=[]
    StarCinema.all_branch_info[self.branch_name]=[]
    print(f"Welcome to {self.branch_name} branch of star cinema!")

  def addMovies(self,*movie_objects):
     for i in movie_objects:
       if i in self.movie_list:
         print(f"Movie is already added in this branch.")
       else:
         self.movie_list.append(i)
         StarCinema.all_branch_info[self.branch_name].append(i)
         print(f"{i.name} added to {self.branch_name} branch.")\

  def removeMovie(self,objects):
      self.movie_list.remove(objects)

  @classmethod
  def check(cls,film):
    boole=False
    for k,v in cls.all_branch_info.items():
      for j in v:
        if j.name==film:
          print(f"{film} is being streamed in {k} branch.")
          boole=True
      if boole!=True:
          print(film,"is not being streamed in any branch.")
      else:
          print(f"It is of {j.genre} genre and {j.duration} minutes duration.")

  @classmethod
  def showAllBranchInfo(cls):
    for x,y in cls.all_branch_info.items():
      print("Branch Name:",x)
      for t in range((len(y))):
        print("Movie No:",(t+1))
        print(y[t].movieInfo())
        print("*********************")
      print("################################")



movie1 = Movie('The Dark Knight Rises', 'Action Thriller', 165)
movie2 = Movie('El Camino', 'Crime Drama', 124)
movie3 = Movie('Mission: Impossible – Dead Reckoning Part One', 'Action', 163)
print(movie2.movieInfo())
print('1==========================================')
print(movie1.movieInfo())
print('2==========================================')
movie4 = Movie.createMovie_fromString('Fast X-Action-141')
print('3==========================================')
print(movie3.movieInfo())
print('4==========================================')
branch1 = StarCinema('Bashundhara')
print('5==========================================')
branch1.addMovies(movie1, movie2, movie3)
print('6==========================================')
branch1.addMovies(movie1, movie3)
print('7==========================================')
StarCinema.showAllBranchInfo()
print('8==========================================')
branch2 = StarCinema('Jamuna Future Park')
print('9==========================================')
branch2.addMovies(movie1, movie2, movie4)
print('10==========================================')
StarCinema.showAllBranchInfo()
print('11==========================================')
StarCinema.check('The Dark Knight Rises')
print('12=========================================')
StarCinema.check('The Shawshank Redemption')
print('13=========================================')
branch1.removeMovie(movie2)
StarCinema.showAllBranchInfo()
print('14=========================================')
branch2.removeMovie(movie1)
StarCinema.showAllBranchInfo()
# Out:
# Movie Name: El Camino
# Movie Genre: Crime Drama
# Movie Duration: 124 minutes
# 1==========================================
# Movie Name: The Dark Knight Rises
# Movie Genre: Action Thriller
# Movie Duration: 165 minutes
# 2==========================================
# 3==========================================
# Movie Name: Mission: Impossible – Dead Reckoning Part One
# Movie Genre: Action
# Movie Duration: 163 minutes
# 4==========================================
# Welcome to Bashundhara branch of star cinema!
# 5==========================================
# The Dark Knight Rises added to Bashundhara branch.
# El Camino added to Bashundhara branch.
# Mission: Impossible – Dead Reckoning Part One added to Bashundhara branch.
# 6==========================================
# Movie is already added in this branch.
# Movie is already added in this branch.
# 7==========================================
# Branch Name: Bashundhara
# Movie No: 1
# Movie Name: The Dark Knight Rises
# ...

# %%
a={}
a["key"]=[23]
a["key"].append(34)
# b=(a.values())
# c=sum(a.values())
print(a)
print(c)
# Out:
# {'key': [23, 34]}
# 23

# %%
v=[1,3,5,7]
che=False
for i in v:
  if i==5:
    print(f"{i} in list")
    che=True
if che==False:
  print("ok")
# Out:
# 5 in list
